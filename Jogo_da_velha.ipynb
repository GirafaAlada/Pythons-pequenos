# %% [markdown]
# <a href="https://colab.research.google.com/github/GirafaAlada/Pythons-pequenos/blob/main/Jogo_da_velha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hora de tentar fazer uma coisa adhihaudhauduahud

# %%
from re import X
#Joguinho da velha
#primeiro vou tentar fazer uma formula que desenha o tabuleiro
jogando = True
jogador_1_vitorioso = False
jogador_2_vitorioso = False
linhas = ['|','-','-','-','-','-','-','-','-','-','|','-','-','-','-','-','-','-','-','-','|','-','-','-','-','-','-','-','-','-','|']
null = ['|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|']
cabecalho_1 = ['|','1',' ',' ',' ',' ',' ',' ',' ',' ','|','2',' ',' ',' ',' ',' ',' ',' ',' ','|','3',' ',' ',' ',' ',' ',' ',' ',' ','|']
espaco_1 = ['|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|']
cabecalho_2 = ['|','4',' ',' ',' ',' ',' ',' ',' ',' ','|','5',' ',' ',' ',' ',' ',' ',' ',' ','|','6',' ',' ',' ',' ',' ',' ',' ',' ','|']
espaco_2 = ['|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|']
cabecalho_3 = ['|','7',' ',' ',' ',' ',' ',' ',' ',' ','|','8',' ',' ',' ',' ',' ',' ',' ',' ','|','9',' ',' ',' ',' ',' ',' ',' ',' ','|']
espaco_3 = ['|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|',' ',' ',' ',' ',' ',' ',' ',' ',' ','|']

#Fórmula que desenha o tabuleiro toda vez
def tabuleiro():
  print(''.join(linhas))
  print(''.join(cabecalho_1))
  print(''.join(espaco_1))
  print(''.join(null))
  print(''.join(linhas))
  print(''.join(cabecalho_2))
  print(''.join(espaco_2))
  print(''.join(null))
  print(''.join(linhas))
  print(''.join(cabecalho_3))
  print(''.join(espaco_3))
  print(''.join(null))
  print(''.join(linhas))

#Variavel que fala de quem é a vez
jogador = 1

#Formula que coloca o X ou O no tabuleiro
def eh_a_hora_do_duelo():
  str(jogada)
  if jogada in cabecalho_1:
    if jogador == 1:
      espaco_1[cabecalho_1.index(jogada) + 4] = 'X'
    else:
      espaco_1[cabecalho_1.index(jogada) + 4] = 'O'
  elif jogada in cabecalho_2:
    if jogador == 1:
      espaco_2[cabecalho_2.index(jogada) + 4] = 'X'
    else:
      espaco_2[cabecalho_2.index(jogada) + 4] = 'O'
  elif jogada in cabecalho_3:
    if jogador == 1:
      espaco_3[cabecalho_3.index(jogada) + 4] = 'X'
    else:
      espaco_3[cabecalho_3.index(jogada) + 4] = 'O'

#Teste pra ver se acabou o jogo
#Já tentei um negocio que não funcionou
#Vou tentar fazer uns conjuntos com as combinações que são vitórias
def vitoria_jogador_1():
  print('Não tem nada aqui')

#Começa o jogo!!!
print('Joguinho da velha!!!')
print('')
print('O jogador 1 é o X. O jogador 2 é o O')

#Fiz um loop com while pra ficar no jogo
while jogando == True:
  tabuleiro()
  jogada = input('Jogador 1, onde vc quer jogar? ')
  eh_a_hora_do_duelo()
  tabuleiro()
  #Ficou assim por enquanto. Depois eu vejo se dá pra colocar em uma função
  if espaco_1[5] == 'X' and espaco_1[15] == 'X' and espaco_1[25] == 'X':
    jogador_1_vitorioso = True
    break
  elif espaco_2[5] == 'X' and espaco_2[15] == 'X' and espaco_2[25] == 'X':
    jogador_1_vitorioso = True
    break
  elif espaco_3[5] == 'X' and espaco_3[15] == 'X' and espaco_3[25] == 'X':
    jogador_1_vitorioso = True
    break
  elif espaco_1[5] == 'X' and espaco_2[15] == 'X' and espaco_3[25] == 'X':
    print('Jogador 1 Ganhou na diagonal')
    break
  elif espaco_1[25] == 'X' and espaco_2[15] == 'X' and espaco_3[5] == 'X':
    jogador_1_vitorioso = True
    break
  elif espaco_1[5] == 'X' and espaco_2[5] == 'X' and espaco_3[5] == 'X':
    jogador_1_vitorioso = True
    break
  elif espaco_1[15] == 'X' and espaco_2[15] == 'X' and espaco_3[15] == 'X':
    jogador_1_vitorioso = True
    break
  elif espaco_1[25] == 'X' and espaco_2[25] == 'X' and espaco_3[25] == 'X':
    jogador_1_vitorioso = True
    break
  jogador = 2
  jogada = input('Jogador 2, onde vc quer jogar? ')
  eh_a_hora_do_duelo()
  if espaco_1[5] == 'O' and espaco_1[15] == 'O' and espaco_1[25] == 'O':
    jogador_2_vitorioso = True
    break
  elif espaco_2[5] == 'O' and espaco_2[15] == 'O' and espaco_2[25] == 'O':
    jogador_2_vitorioso = True
    break
  elif espaco_3[5] == 'O' and espaco_3[15] == 'O' and espaco_3[25] == 'O':
    jogador_2_vitorioso = True
    break
  elif espaco_1[5] == 'O' and espaco_2[15] == 'O' and espaco_3[25] == 'O':
    jogador_2_vitorioso = True
    break
  elif espaco_1[25] == 'O' and espaco_2[15] == 'O' and espaco_3[5] == 'O':
    jogador_2_vitorioso = True
    break
  elif espaco_1[5] == 'O' and espaco_2[5] == 'O' and espaco_3[5] == 'O':
    jogador_2_vitorioso = True
    break
  elif espaco_1[15] == 'O' and espaco_2[15] == 'O' and espaco_3[15] == 'O':
    jogador_2_vitorioso = True
    break
  elif espaco_1[25] == 'O' and espaco_2[25] == 'O' and espaco_3[25] == 'O':
    jogador_2_vitorioso = True
    break
  jogador = 1

tabuleiro()
jogando = False
if jogador_1_vitorioso == True:
  print('Parabéns jogador 1! Você é o bixão!')
elif jogador_2_vitorioso == True:
  print('Parabéns jogador 2! Você é o bixão!')
# Out:
# Joguinho da velha!!!
#
# O jogador 1 é o X. O jogador 2 é o O
# |---------|---------|---------|
# |1        |2        |3        |
# |         |         |         |
# |         |         |         |
# |---------|---------|---------|
# |4        |5        |6        |
# |         |         |         |
# |         |         |         |
# |---------|---------|---------|
# |7        |8        |9        |
# |         |         |         |
# |         |         |         |
# |---------|---------|---------|
# Jogador 1, onde vc quer jogar? 3
# |---------|---------|---------|
# |1        |2        |3        |
# |         |         |    X    |
# |         |         |         |
# |---------|---------|---------|
# |4        |5        |6        |
# |         |         |         |
# |         |         |         |
# |---------|---------|---------|
# |7        |8        |9        |
# |         |         |         |
# |         |         |         |
# |---------|---------|---------|
# ...

# %%
print(espaco_1)
print(espaco_2)
print(espaco_3)
# Out:
# ['|', ' ', ' ', ' ', ' ', 'X', ' ', ' ', ' ', ' ', '|', ' ', ' ', ' ', ' ', 'O', ' ', ' ', ' ', ' ', '|', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '|']
# ['|', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '|', ' ', ' ', ' ', ' ', 'X', ' ', ' ', ' ', ' ', '|', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '|']
# ['|', ' ', ' ', ' ', ' ', 'O', ' ', ' ', ' ', ' ', '|', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '|', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '|']
